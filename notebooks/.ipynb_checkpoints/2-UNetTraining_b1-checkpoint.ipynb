# %% [markdown]
#   Author: Ankit Kariryaa, University of Bremen
#
#   Modified by Xuehui Pi and Qiuqi Luo

# %% [markdown]
# ### Getting started
# Define the paths for the dataset and trained models in the `notebooks/config/UNetTraining.py` file.

# %%
import os
os.environ["MKL_NUM_THREADS"] = '16'
os.environ["NUMEXPR_NUM_THREADS"] = '16'
os.environ["OMP_NUM_THREADS"] = '16'
print(os.environ.get('OMP_NUM_THREADS'))
# Out:
# 16

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import rasterio
import imgaug as ia
from imgaug import augmenters as iaa
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import imageio
import os
import random
import time
import rasterio.warp             # Reproject raster samples
from functools import reduce
from tensorflow.keras.models import load_model
from tensorflow.keras import mixed_precision 
mixed_precision.set_global_policy('mixed_float16')

from core.UNet import UNet  #
from core.losses import tversky, accuracy, dice_loss, IoU, recall, precision,F1_score
from core.optimizers import adaDelta, adagrad, adam, nadam
from core.frame_info import FrameInfo
from core.dataset_generator import DataGenerator
from core.visualize import display_images,plot

import json
from sklearn.model_selection import train_test_split
import pickle
# %matplotlib inline
import matplotlib.pyplot as plt  # plotting tools
import matplotlib.patches as patches
from matplotlib.patches import Polygon
#matplotlib.use("Agg")

import warnings                  # ignore annoying warnings
warnings.filterwarnings("ignore")
import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

# %reload_ext autoreload
# %autoreload 2
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#Mixed precision is the use of both 16-bit and 32-bit floating-point types in a model during training to make it run faster and use less memory.
os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'

print(tf.__version__)
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3090, compute capability 8.6
# 2.9.0

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto(
    #device_count={"CPU": 64},
    allow_soft_placement=True, 
    log_device_placement=False)
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# Required configurations (including the input and output paths) are stored in a separate file (such as config/UNetTraining.py)
# Please provide required info in the file before continuing with this notebook. 
from config import UNetTraining
# In case you are using a different folder name such as configLargeCluster, then you should import from the respective folder 
# Eg. from configLargeCluster import UNetTraining
config = UNetTraining.Configuration()

# %% [markdown]
# ## 读取训练、验证、测试数据集

# %%
def readFrames(dataType):
    frames=[]
    numList=[]
    print(dataType)
    for i in range(1,7):
#         path_to_write=r'/home/nkd/hbh/normal/patchesReshape/{}/type{}'.format(dataType,i)
        path_to_write=r'D:\lakemapping\2_dataset\osw\patchesReshape\{}\type{}'.format(dataType,i)
#         path_to_write2=r'D:\lakemapping\3_training\U-Net\patchesReshape\{}\type{}'.format(dataType,i)
#         path_to_write=os.path.join(config.base_dir,r'patchesReshape\{}\type{}'.format(dataType,i))
        all_files = os.listdir(path_to_write)
        all_files_GSW = [fn for fn in all_files if fn.startswith(config.GSW_fn) and fn.endswith(config.image_type)]#ndwi.png
        print('type{} image number:{}'.format(i,len(all_files_GSW)))
        for j, fn in enumerate(all_files_GSW):
            GSW_img = rasterio.open(os.path.join(path_to_write, fn))
            read_GSW_img = GSW_img.read()
            rowNum=read_GSW_img.shape[1]/config.patch_size[0]
            colNum=read_GSW_img.shape[2]/config.patch_size[1]
            num=rowNum*colNum
            comb_img = np.transpose(read_GSW_img, axes=(1,2,0)) #Channel at the end  ( , ,1) 
            annotation_im = Image.open(os.path.join(path_to_write, fn.replace(config.GSW_fn,config.annotation_fn)))
            annotation = np.array(annotation_im)
            f = FrameInfo(comb_img, annotation)
            frames.append(f)
            numList.append(num)
    return frames,numList

# %%
frames,numList=readFrames('train')
percentages=np.array(numList)
print(percentages.sum())
train_sum=percentages.sum()
# percentages=np.ones(len(numList))/len(frames)
percentages=percentages/percentages.sum()
# frames=readFrames('train')
print('total training img count:'+str(len(frames)))
train_generator = DataGenerator(config.input_image_channel, config.patch_size, frames, config.input_label_channel, augmenter = 'iaa').random_generator(config.BATCH_SIZE,percentages)#,normalize = config.normalize
# Out:
# train
# type1 image number:112
# type2 image number:96
# type3 image number:133
# type4 image number:160
# type5 image number:6
# type6 image number:3
# 6399.978778839111
# total training img count:510

# %%
frames,numList=readFrames('val')
percentages=np.array(numList)
print(percentages.sum())
val_sum=percentages.sum()
# percentages=np.ones(len(numList))/len(frames)
percentages=percentages/percentages.sum()
# frames=readFrames('val')
print('total validation img count:'+str(len(frames)))
val_generator = DataGenerator(config.input_image_channel, config.patch_size, frames, config.input_label_channel, augmenter = None).random_generator(config.BATCH_SIZE,percentages)#, normalize = config.normalize
# Out:
# val
# type1 image number:28
# type2 image number:24
# type3 image number:34
# type4 image number:41
# type5 image number:2
# type6 image number:1
# 1074.3656311035156
# total validation img count:130

# %%
for _ in range(1):
    train_images, real_label = next(train_generator) 
#     print(train_images.Length())
    display_images(np.concatenate((train_images,real_label), axis = -1))

# %%
for _ in range(1):
    val_images, val_label = next(val_generator) 
    print(val_images.shape)
    display_images(np.concatenate((val_images,val_label), axis = -1))
# Out:
# (16, 512, 512, 1)

# %% [markdown]
# ## 参数初始化

# %%
OPTIMIZER = adaDelta
OPTIMIZER = mixed_precision.LossScaleOptimizer(OPTIMIZER)
OPTIMIZER_NAME = 'AdaDelta'

# OPTIMIZER = adam
# OPTIMIZER = mixed_precision.LossScaleOptimizer(OPTIMIZER)
# OPTIMIZER_NAME = 'adam'

# %%
LOSS = tversky 
LOSS_NAME = 'tversky'

# LOSS=focalTversky
# LOSS_NAME = 'focalTversky'

#LOSS=tf.keras.losses.BinaryCrossentropy()
#LOSS_NAME = 'bce'

# LOSS=bce_dice_loss
# LOSS_NAME = 'bce_dice_loss'

# LOSS=dice_loss
# LOSS_NAME = 'dice_loss'

# %%
timestr = time.strftime("%Y%m%d-%H%M")
chf = config.input_image_channel + config.input_label_channel
chs = reduce(lambda a,b: a+str(b), chf, '') 

if not os.path.exists(config.model_path):
    os.makedirs(config.model_path)
model_name='_{}_{}_{}_{}_{}.h5'.format(timestr,OPTIMIZER_NAME,LOSS_NAME,chs,config.input_shape[0])
model_path = os.path.join(config.model_path,'lakes'+model_name)

chf = config.input_image_channel + config.input_label_channel
chs = reduce(lambda a,b: a+str(b), chf, '') 
print(model_path)
# Out:
# D:\lakemapping\U_Net_GSW\saved_models/UNet\lakes_20240229-2118_AdaDelta_tversky_01_512.h5

# %%
# Define the model and compile it  
model = UNet([config.BATCH_SIZE, *config.input_shape],config.input_label_channel)
model.compile(optimizer=OPTIMIZER, loss=LOSS, metrics=[accuracy,dice_loss, recall, precision,F1_score, IoU])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  Input (InputLayer)             [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 64  640         ['Input[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
# ...

# %%
# Define callbacks      for the early stopping of training, LearningRateScheduler and model checkpointing 
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau, TensorBoard

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only = False)

#reduceonplatea： It can be useful when using adam as optimizer
#Reduce learning rate when a metric has stopped improving (after some patience 个epoch, reduce by a factor of 0.33, new_lr = lr * factor). 
#cooldown: number of epochs to wait before resuming normal operation after lr has been reduced. 

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.33,
                                   patience=4, verbose=1, mode='min',
                                   min_delta=0.0001, cooldown=4, min_lr=1e-16) 

early = EarlyStopping(monitor="val_loss", mode="min", verbose=2, patience=100)


log_dir = os.path.join('./logs','UNet_{}_{}_{}_{}_{}'.format(timestr,OPTIMIZER_NAME,LOSS_NAME,chs, config.input_shape[0]))
tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None, embeddings_data=None, update_freq='epoch')

callbacks_list = [checkpoint, tensorboard, early] #reduceLROnPlat is not required with adaDelta

# %%
loss_history = model.fit(train_generator, 
                         steps_per_epoch=config.MAX_TRAIN_STEPS,#train_sum//config.BATCH_SIZE,#
                         epochs=config.NB_EPOCHS, 
                         validation_data=val_generator,
                         validation_steps=config.VALID_IMG_COUNT,#val_sum//config.BATCH_SIZE,#
                         callbacks=callbacks_list,
                         workers=1,
#                          shuffle=True,
#                          use_multiprocessing=True # the generator is not very thread safe 
                         #max_queue_size = 60,
                        )
h=loss_history.history
with open('history{}_{}_{}_{}_{}_{}_{}.txt'.format(OPTIMIZER_NAME,LOSS_NAME,config.input_shape[0], config.NB_EPOCHS, config.BATCH_SIZE,chs,timestr), 'wb') as file_pi:
    pickle.dump(h, file_pi)
plot(h, OPTIMIZER_NAME,LOSS_NAME, config.patch_size[0], config.NB_EPOCHS, config.BATCH_SIZE,chs)
# Out:
# Epoch 1/200
# 750/750 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9887 - dice_loss: 0.0497 - recall: 0.9778 - precision: 0.9299 - F1_score: 0.9511 - IoU: 0.9116
# Epoch 1: val_loss improved from inf to 0.04986, saving model to D:\lakemapping\U_Net_GSW\saved_models/UNet\lakes_20240229-2118_AdaDelta_tversky_01_512.h5
# 750/750 [==============================] - 1465s 2s/step - loss: 0.0499 - accuracy: 0.9887 - dice_loss: 0.0497 - recall: 0.9778 - precision: 0.9299 - F1_score: 0.9511 - IoU: 0.9116 - val_loss: 0.0499 - val_accuracy: 0.9869 - val_dice_loss: 0.0496 - val_recall: 0.9780 - val_precision: 0.9275 - val_F1_score: 0.9507 - val_IoU: 0.9090
# Epoch 2/200
# 750/750 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9911 - dice_loss: 0.0380 - recall: 0.9837 - precision: 0.9445 - F1_score: 0.9622 - IoU: 0.9300
# ...

# %%
# # 读取现有history文件
# with open('.txt','rb')as file_pi:
#     h=pickle.load(file_pi)
# print(h)

# %%
# plot(h, OPTIMIZER_NAME,LOSS_NAME, config.patch_size[0], config.NB_EPOCHS, config.BATCH_SIZE,chs)

# %% [markdown]
# ## 总体精度评价

# %%
# Load model after training 
# If you load a model with different python version, than you may run into a problem: https://github.com/keras-team/keras/issues/9595#issue-303471777
model = load_model(model_path, custom_objects={'tversky': LOSS, 'accuracy':accuracy ,'recall':recall,'precision':precision,'F1_score':F1_score,'IoU': IoU}, compile=False) 
model.compile(optimizer=OPTIMIZER, loss=LOSS, metrics=[accuracy,recall,precision,F1_score,IoU])

# %%
frames=readFrames('test')
percentages=np.array(numList)
percentages=percentages/percentages.sum()
print('total validation img count:'+str(len(frames)))
test_generator = DataGenerator(config.input_image_channel, config.patch_size, frames, config.input_label_channel, augmenter = None).random_generator(config.BATCH_SIZE,percentages)
print('done')

# %%
frames=readFrames('test')#,sample_factor
test_patches = DataGenerator(config.input_image_channel, config.patch_size, frames, config.input_label_channel, augmenter = None).all_sequential_patches(config.step_size)
print('test patchs number:',len(test_patches[0]))
# Out:
# test
# type1 image number:36
# type2 image number:30
# type3 image number:42
# type4 image number:51
# type5 image number:2
# type6 image number:1
# test patchs number: 1453

# %%
ev=model.evaluate(test_patches[0],test_patches[1],config.BATCH_SIZE)
ev.append(len(test_patches[0]))
# Out:
# 90/91 [============================>.] - ETA: 0s - loss: 0.0315 - accuracy: 0.9960 - dice_loss: 0.0136 - recall: 0.9856 - precision: 0.9648 - F1_score: 0.9685 - IoU: 0.9531
# 2024-02-29 20:26:26.924787: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# 2024-02-29 20:26:27.720097: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# ...

# %% [markdown]
# ## 分类别精度评价

# %%
ev_list=[]
for i in range(1,7):
    frames=[]
    test_patchs_type=[]
    path_to_write='/home/nkd/hbh/normal/patchesReshape/test/type{}'.format(i)
    all_files = os.listdir(path_to_write)
    all_files_GSW = [fn for fn in all_files if fn.startswith(config.GSW_fn) and fn.endswith(config.image_type)]#ndwi.png
    print('type{} image number:{}'.format(i,len(all_files_GSW)))
    for j, fn in enumerate(all_files_GSW):
        GSW_img = rasterio.open(os.path.join(path_to_write, fn))
        read_GSW_img = GSW_img.read()
        comb_img = np.transpose(read_GSW_img, axes=(1,2,0)) #Channel at the end  ( , ,1) 
        annotation_im = Image.open(os.path.join(path_to_write, fn.replace(config.GSW_fn,config.annotation_fn)))
        annotation = np.array(annotation_im)
        f = FrameInfo(comb_img, annotation)
        frames.append(f)
    test_patchs_type = DataGenerator(config.input_image_channel, config.patch_size, frames, config.input_label_channel, augmenter = None).all_sequential_patches(config.step_size)
    print('type{} patches number:{}'.format(i,len(test_patchs_type[0])))
    ev2 = model.evaluate(test_patchs_type[0],test_patchs_type[1],config.BATCH_SIZE,verbose=1)
    ev2.append(len(test_patchs_type[0]))
    ev_list.append(ev2)
    del frames,test_patchs_type
# Out:
# type1 image number:36
# type1 patches number:365
# 23/23 [==============================] - 4s 162ms/step - loss: 0.0102 - accuracy: 0.9988 - dice_loss: 0.0107 - recall: 0.9875 - precision: 0.9922 - F1_score: 0.9898 - IoU: 0.9800
# type2 image number:30
# type2 patches number:644
# 40/41 [============================>.] - ETA: 0s - loss: 0.0060 - accuracy: 0.9968 - dice_loss: 0.0122 - recall: 0.9905 - precision: 0.9978 - F1_score: 0.9940 - IoU: 0.9884
# 2024-02-29 20:28:32.413791: W tensorflow/stream_executor/gpu/asm_compiler.cc:235] Your CUDA software stack is old. We fallback to the NVIDIA driver for some compilation. Update your CUDA version to get the best performance. The ptxas error was: ptxas fatal   : Value 'sm_86' is not defined for option 'gpu-name'
#
# ...

# %%
#old_model_parameter
print('      patch_num   loss  accuracy  dice_loss recall  precision  F1_score    IoU')
print('total:{:^9}{:^9.3f}{:^9.3f}{:^9.3f} {:^9.3f} {:^9.3f} {:^9.3f} {:^9.3f}'.format(ev[-1],ev[0],ev[1],ev[2],ev[3],ev[4],ev[5],ev[6]))
for i in range(0,6):
    print('type{}:{:^9}{:^9.3f}{:^9.3f}{:^9.3f} {:^9.3f} {:^9.3f} {:^9.3f} {:^9.3f}'.format(i+1,ev_list[i][-1],ev_list[i][0],ev_list[i][1],ev_list[i][2],ev_list[i][3],ev_list[i][4],ev_list[i][5],ev_list[i][6]))
# Out:
#       patch_num   loss  accuracy  dice_loss recall  precision  F1_score    IoU
# total:  1453     0.032    0.996    0.014     0.985     0.964     0.968     0.952
# type1:   365     0.010    0.999    0.011     0.988     0.992     0.990     0.980
# type2:   644     0.006    0.997    0.012     0.991     0.998     0.994     0.989
# type3:   230     0.008    0.998    0.011     0.989     0.994     0.992     0.983
# type4:   209     0.175    0.986    0.026     0.953     0.809     0.830     0.773
# type5:    4      0.058    0.977    0.034     0.953     0.932     0.942     0.891
# type6:    1      0.001    1.000    0.019     1.000     0.998     0.999     0.998

# %%
#old_model pi
print('      patch_num   loss  accuracy   recall  precision  F1_score    IoU')
print('total:{:^9}{:^9.3f}{:^9.3f}{:^9.3f} {:^9.3f} {:^9.3f} {:^9.3f}'.format(ev[-1],ev[0],ev[1],ev[2],ev[3],ev[4],ev[5]))
for i in range(0,6):
    print('type{}:{:^9}{:^9.3f}{:^9.3f}{:^9.3f} {:^9.3f} {:^9.3f} {:^9.3f}'.format(i+1,ev_list[i][6],ev_list[i][0],ev_list[i][1],ev_list[i][2],ev_list[i][3],ev_list[i][4],ev_list[i][5]))
# Out:
#       patch_num   loss  accuracy   recall  precision  F1_score    IoU
# total:  1453     0.038    0.995    0.984     0.955     0.961     0.942
# type1:   365     0.012    0.999    0.986     0.990     0.988     0.977
# type2:   644     0.007    0.996    0.989     0.997     0.993     0.986
# type3:   230     0.008    0.998    0.989     0.993     0.991     0.983
# type4:   209     0.207    0.982    0.952     0.770     0.806     0.743
# type5:    4      0.060    0.976    0.958     0.923     0.940     0.888
# type6:    1      0.003    1.000    1.000     0.993     0.996     0.993

# %%
print('      patch_num   loss  accuracy   recall  precision  F1_score    IoU')
print('total:{:^9}{:^9.3f}{:^9.3f}{:^9.3f} {:^9.3f} {:^9.3f} {:^9.3f}'.format(ev[-1],ev[0],ev[1],ev[2],ev[3],ev[4],ev[5]))
for i in range(0,6):
    print('type{}:{:^9}{:^9.3f}{:^9.3f}{:^9.3f} {:^9.3f} {:^9.3f} {:^9.3f}'.format(i+1,ev_list[i][6],ev_list[i][0],ev_list[i][1],ev_list[i][2],ev_list[i][3],ev_list[i][4],ev_list[i][5]))
# Out:
#       patch_num   loss  accuracy   recall  precision  F1_score    IoU
# total:  1453     0.040    0.995    0.988     0.951     0.960     0.942
# type1:   365     0.012    0.999    0.989     0.986     0.988     0.976
# type2:   644     0.006    0.998    0.992     0.997     0.994     0.989
# type3:   230     0.008    0.998    0.992     0.992     0.992     0.984
# type4:   209     0.218    0.980    0.965     0.744     0.794     0.724
# type5:    4      0.063    0.974    0.959     0.916     0.937     0.881
# type6:    1      0.003    1.000    1.000     0.995     0.997     0.994

# %%
i=1
test_img_type=test_patchs_type[0][i*config.BATCH_SIZE:i*config.BATCH_SIZE+config.BATCH_SIZE]
test_ann_type=test_patchs_type[1][i*config.BATCH_SIZE:i*config.BATCH_SIZE+config.BATCH_SIZE]
prediction = model.predict(test_img_type, steps=1)
prediction[prediction>0.5]=1
prediction[prediction<=0.5]=0
display_images(np.concatenate((test_img_type, test_ann_type, prediction), axis = -1))# test_images( GSW), real_label(label), prediction_
